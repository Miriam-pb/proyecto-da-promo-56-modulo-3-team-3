# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", None)

# %%
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("csv_completo.csv")

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1678, step=1)

# %%
df_zara= df[["environmentsatisfaction", "gender", "hourlyrate", "jobinvolvement", "joblevel", "jobrole", "jobsatisfaction", "maritalstatus", "monthlyincome", "monthlyrate" ]]

# %%
df_zara
# Out:
#       environmentsatisfaction  gender  hourlyrate  jobinvolvement  joblevel  \
# 0                           1    male      251.97               3         5
# 1                           3    male      257.92               2         5
# 2                           3    male      248.03               3         5
# 3                           1  female      221.43               3         4
# 4                           1  female      197.85               4         4
# ...                       ...     ...         ...             ...       ...
# 1673                        2  female       61.12               4         1
# 1674                        4  female      246.75               3         5
# 1675                        3    male       36.25               3         1
# 1676                        3  female      129.06               2         3
# 1677                        4  female       69.53               3         2
#
# ...

# %%
df_zara["environmentsatisfaction"].isna().sum()
# Out:
# np.int64(0)

# %%
df_zara["gender"].isna().sum()
# Out:
# np.int64(0)

# %%
df_zara.isna().sum()
# Out:
# environmentsatisfaction      0
# gender                       0
# hourlyrate                   0
# jobinvolvement               0
# joblevel                     0
# jobrole                      0
# jobsatisfaction              0
# maritalstatus              675
# monthlyincome                0
# monthlyrate                  0
# dtype: int64

# %%
df_zara["maritalstatus"].isna().sum()
# Out:
# np.int64(675)

# %%
df
# Out:
#       age attrition businesstravel  dailyrate              department  \
# 0      51        No            NaN    2015.72                     NaN
# 1      52        No            NaN    2063.39                     NaN
# 2      42        No  travel_rarely    1984.25  research & development
# 3      47        No  travel_rarely    1771.40                     NaN
# 4      46        No            NaN    1582.77                     NaN
# ...   ...       ...            ...        ...                     ...
# 1673   43        No            NaN     488.94                     NaN
# 1674   47        No            NaN    1973.98                     NaN
# 1675   29        No  travel_rarely     290.04                     NaN
# 1676   47        No  travel_rarely    1032.49                     NaN
# 1677   32        No            NaN     556.26                     NaN
#
#       education    educationfield  employeecount  employeenumber  \
# ...
